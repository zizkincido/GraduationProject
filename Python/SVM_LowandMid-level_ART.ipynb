# %%
from sklearn import svm
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
column=['pca0','pca1','pca2','pca3','pca4','pca5','pca6',
        'pca7','pca8','pca9','pca10','pca11','pca12','pca13',
        'pca14','pca15','pca16','pca17','pca18','pca19','pca20',
        'pca21','pca22','pca23','pca24','pca25','pca26','pca27',
        'pca28','pca29','pca30','pca31','pca32','pca33','pca34',
        'pca35','pca36','pca37','pca38','pca39','pca40','pca41',
        'pca42','pca43','pca44','pca45','pca46','pca47','pca48','pca49']

# %%
df_lowmid_art = pd.read_csv(r"C:\Users\Aziz\Desktop\Github\CSV\LowAndMidMergedFeatured_ART.csv")
df_lowmid_art
df_lowmid_art = df_lowmid_art.dropna()
like_rate = pd.DataFrame()
like_rate['like_rate_segmentation'] = df_lowmid_art['like_rate_segmentation.1']
df_lowmid_art.pop('like_rate_segmentation')
df_lowmid_art.pop('Unnamed: 0')
df_lowmid_art.pop('like_rate_segmentation.1')
pca = PCA(n_components=50) # 2 dimensional PCA
pca.fit(df_lowmid_art)
df_pca = pca.transform(df_lowmid_art) 
df = pd.DataFrame(data=df_pca,columns=column)
df['like_rate_segmentation'] = like_rate['like_rate_segmentation']
# Out:
#               pca0           pca1           pca2           pca3  \
# 0    148878.653196 -116557.599318  -30773.769852  175402.846023
# 1    469202.626064  732975.669099 -163175.282088 -366490.748410
# 2    215881.723946  777298.087629 -176348.078784 -321055.273664
# 3   -291731.037524  211534.608737  -33727.816364  528897.725359
# 4    542931.478209 -523215.642541 -139199.664172   95099.391674
# ..             ...            ...            ...            ...
# 779 -246219.682408   10059.019010  -73313.176434  259180.268969
# 780 -201742.323238  -58112.102296   -6142.858474    1398.596730
# 781 -129503.279449  -75458.526624 -108188.886759   -8481.778444
# 782  -47393.182087  269752.385833 -167368.513094   79210.195928
# 783 -152577.809018  -34757.746768 -121611.526939   85609.808365
#
#               pca4           pca5           pca6           pca7  \
# 0   -127221.963468 -158982.847919 -106983.571851  -65802.165636
# 1   -276449.241493   32058.093415  369379.692314  -62685.054415
# 2    349764.993903 -445812.905524   36807.549247 -426215.063128
# 3    265337.600551  438030.402610  112889.388901   36356.209539
# 4    369027.705073 -286772.188649  519453.143194  355077.644812
# ..             ...            ...            ...            ...
# 779 -196531.402407   -7213.329157  218566.885839 -196913.354857
# 780 -203650.750939 -193379.404277  -57040.169460  108749.643620
# 781 -144207.414109  -86771.123177 -108155.698772    2332.918744
# 782  155405.135794 -185841.947206 -187596.504336   53822.587952
# 783 -199816.189981 -148244.554875  -29922.919882   15892.421674
#
#               pca8           pca9  ...        pca41        pca42        pca43  \
# 0    -68996.072755   -6211.560760  ... -1753.624394 -5620.072465 -6607.523958
# 1   -414693.892555 -416804.677751  ...   -40.832580   510.323918  -489.888786
# 2    238249.578091  482100.557892  ...  -202.628125   817.904111 -1175.817401
# 3   -347067.076459   56615.277882  ...  1329.862382  3413.594033  5208.332491
# 4    -44567.488034  108627.423861  ...   394.792322  1657.282870   470.484319
# ..             ...            ...  ...          ...          ...          ...
# 779  234043.542146   -9679.317697  ...  -601.606951 -2082.983358 -2058.034381
# 780  -73210.654566   29185.543271  ...  -968.507776 -1999.576371 -3376.746849
# 781  -89481.418406   69818.725099  ...  -765.858860   -79.806499 -7845.785498
# 782  109230.810009   20690.524885  ... -1083.146488 -3319.917016 -4119.905509
# 783   19155.431607  -12726.430227  ... -1979.686888 -6472.181981 -8324.651557
#
#            pca44         pca45        pca46        pca47         pca48  \
# 0    7895.227974 -10414.845933 -3160.446359 -6017.977970  -7494.068554
# 1     544.026255   1870.010652  1099.803450  1141.986248   2853.349978
# 2    1635.652806   3442.399813  2191.480888  2169.539181   5621.371124
# 3   -5925.278253   4010.981033   323.645967  2359.829194    234.434219
# 4    -839.819453   2480.686740   969.376939  1588.902248   2443.786897
# ..           ...           ...          ...          ...           ...
# 779  3263.661307  -4346.907309 -1363.040081 -2338.562461  -3402.287441
# 780  5367.279446  -2826.707177   -22.760252 -1662.218376    186.002141
# 781  7720.518172  -2192.542609   323.320235 -1157.279505   -211.411547
# 782  5088.542077  -6036.001341 -1709.855903 -3461.818904  -4009.615361
# 783  9135.153836 -13002.574108 -4202.142479 -7564.548965 -10034.141441
#
#            pca49  like_rate_segmentation
# 0    -925.139393                     2.0
# 1      65.684362                     2.0
# 2      98.095090                     2.0
# 3     513.175098                     3.0
# 4     234.087486                     3.0
# ..           ...                     ...
# 779  -501.651953                     1.0
# 780  -353.865330                     1.0
# 781  -391.175917                     1.0
# 782  -539.574675                     1.0
# 783 -1076.107636                     3.0
#
# [784 rows x 51 columns]

# %%
X = df.iloc[:, :-1]
y = df.loc[:, 'like_rate_segmentation']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state = 0)

# %%
linear = svm.SVC(kernel='linear', C=1, decision_function_shape='ovo').fit(X_train, y_train)
rbf = svm.SVC(kernel='rbf', gamma=1, C=1, decision_function_shape='ovo').fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=3, C=1, decision_function_shape='ovo').fit(X_train, y_train)
sig = svm.SVC(kernel='sigmoid', C=1, decision_function_shape='ovo').fit(X_train, y_train)

# %%
linear_pred = linear.predict(X_test)
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)
sig_pred = sig.predict(X_test)

# %%
poly_accuracy = accuracy_score(y_test, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
lin_accuracy = accuracy_score(y_test, linear_pred)
lin_f1 = f1_score(y_test, linear_pred, average='weighted')
print('Accuracy (linear Kernel): ', "%.2f" % (lin_accuracy*100))
print('F1 (linear Kernel): ', "%.2f" % (lin_f1*100))
sig_accuracy = accuracy_score(y_test, sig_pred)
sig_f1 = f1_score(y_test, sig_pred, average='weighted')
print('Accuracy (sig Kernel): ', "%.2f" % (sig_accuracy*100))
print('F1 (sig Kernel): ', "%.2f" % (sig_f1*100))
