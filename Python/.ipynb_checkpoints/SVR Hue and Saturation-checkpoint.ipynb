# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\Aziz\Desktop\Github\CSV\Average_hsv_arc.csv")
like_rate = pd.read_csv(r"C:\Users\Aziz\Desktop\Github\CSV\dataset_info_by_date_arc.csv")
dataset['like_rate']=like_rate['like_rate']
dataset.pop('Unnamed: 0')

X = dataset.iloc[:, 0:1].values
y = dataset.iloc[:, 2:3].values
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)
X_grid = np.arange(min(X), max(X), 0.01) #this step required because data is feature scaled.
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('SVR')
plt.xlabel('Average Hue ARC')
plt.ylabel('Like Rate')
plt.show()
# Out:
# C:\Users\Aziz\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
#Saturation
X = dataset.iloc[:, 1:2].values
sc_X = StandardScaler()
X = sc_X.fit_transform(X)
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)
X_grid = np.arange(min(X), max(X), 0.01) #this step required because data is feature scaled.
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('SVR')
plt.xlabel('Average Saturation ARC')
plt.ylabel('Like Rate')
plt.show()
# Out:
# C:\Users\Aziz\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
dataset = pd.read_csv(r"C:\Users\Aziz\Desktop\Github\CSV\Average_hsv_art.csv")
like_rate = pd.read_csv(r"C:\Users\Aziz\Desktop\Github\CSV\dataset_info_by_date_art.csv")
dataset['like_rate']=like_rate['like_rate']
dataset.pop('Unnamed: 0')

X = dataset.iloc[:, 0:1].values
y = dataset.iloc[:, 2:3].values
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y)
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)
X_grid = np.arange(min(X), max(X), 0.01) #this step required because data is feature scaled.
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('SVR')
plt.xlabel('Average Hue ART')
plt.ylabel('Like Rate')
plt.show()
# Out:
# C:\Users\Aziz\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
X = dataset.iloc[:, 1:2].values
sc_X = StandardScaler()
X = sc_X.fit_transform(X)
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)
X_grid = np.arange(min(X), max(X), 0.01) #this step required because data is feature scaled.
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('SVR')
plt.xlabel('Average Saturation ART')
plt.ylabel('Like Rate')
plt.show()
# Out:
# C:\Users\Aziz\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
