# %%
from sklearn import svm
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
df_low_arc = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\LowMergedFeatured_ARC.csv")
df_low_arc.pop('Unnamed: 0')
df_low_arc
like_rate = pd.DataFrame()
like_rate['like_rate_segmentation'] = df_low_arc['like_rate_segmentation.1']
df_low_arc.pop('like_rate_segmentation')
df_low_arc.pop('like_rate_segmentation.1')
df = df_low_arc
df['like_rate_segmentation'] = like_rate['like_rate_segmentation']
df
# Out:
#           Hue  Saturation  dominant_hue_1  dominant_sat_1  dominant_val_1  \
# 0    0.082535    0.600846        0.055656        0.626374        0.356863
# 1    0.603184    0.544172        1.000000        0.375510        0.960784
# 2    0.588661    0.286094        0.588987        0.535714        0.878431
# 3    0.414506    0.262685        0.556962        0.016304        0.721569
# 4    0.612429    0.137158        0.605696        0.033473        0.937255
# ..        ...         ...             ...             ...             ...
# 802  0.347530    0.370677        0.941176        0.140811        0.763780
# 803  0.718663    0.060688        1.000000        0.013503        0.937008
# 804  0.962266    1.000000        0.954220        0.094895        1.000000
# 805  1.000000    1.000000        1.000000        1.000000        0.947154
# 806  1.000000    1.000000        1.000000        0.406504        1.000000
#
#      dominant_hue_2  dominant_sat_2  dominant_val_2  dominant_hue_3  \
# 0          0.064668        0.213974        0.898039        0.061573
# 1          0.996149        0.620112        0.701961        0.152181
# 2          0.594768        0.353191        0.921569        0.111418
# 3          0.472532        0.387097        0.121569        0.668508
# 4          0.594140        0.228571        0.549020        0.577348
# ..              ...             ...             ...             ...
# 802        0.175019        0.309497        0.200000        0.107143
# 803        1.000000        0.514564        0.446809        1.000000
# 804        0.967098        1.000000        0.906383        0.795455
# 805        1.000000        1.000000        1.000000        1.000000
# 806        1.000000        1.000000        1.000000        1.000000
#
#      dominant_sat_3  ...  laplacian42  laplacian43  laplacian44  laplacian45  \
# 0          0.808511  ...     0.415385     0.493311     0.454089     0.337253
# 1          1.000000  ...     0.442909     0.408165     0.487367     0.228722
# 2          0.029126  ...     0.373614     0.422806     0.551235     0.441416
# 3          0.044944  ...     0.421116     0.430185     0.471664     0.438950
# 4          0.123596  ...     0.485569     0.583957     0.516850     0.283275
# ..              ...  ...          ...          ...          ...          ...
# 802        0.239044  ...     0.000000     0.138438     0.787121     0.205787
# 803        0.271084  ...     0.000000     0.504173     0.000000     0.085747
# 804        0.467836  ...     0.587325     0.777275     0.000000     0.126369
# 805        1.000000  ...     0.034085     0.404704     0.188088     0.275776
# 806        1.000000  ...     0.000000     0.000000     0.000000     0.000000
#
#      laplacian46  laplacian47  laplacian48  laplacian49  Brightness  \
# 0       0.310955     0.345285     0.402359     0.370145    0.303450
# 1       0.394826     0.141635     0.533573     0.549273    0.630317
# 2       0.296606     0.441490     0.555423     0.497900    0.733562
# 3       0.428365     0.393137     0.416056     0.385750    0.627026
# 4       0.368126     0.500109     0.510297     0.388084    0.675688
# ..           ...          ...          ...          ...         ...
# 802     0.399252     0.410330     0.000000     0.539974    0.993197
# 803     0.202129     0.162891     0.171905     0.000000    0.900213
# 804     0.328785     0.324442     0.130762     0.220086    0.906471
# 805     0.386639     0.000000     0.000000     0.101934    1.000000
# 806     0.000000     0.314025     0.473945     0.509895    1.000000
#
#      like_rate_segmentation
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
# ..                      ...
# 802                       5
# 803                       5
# 804                       5
# 805                       5
# 806                       5
#
# [807 rows x 77 columns]

# %%
X = df.iloc[:, :-1]
y = df.loc[:, 'like_rate_segmentation']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state = 0)

# %%
linear = svm.SVC(kernel='linear', C=1, decision_function_shape='ovo').fit(X_train, y_train)
rbf = svm.SVC(kernel='rbf', gamma=1, C=1, decision_function_shape='ovo').fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=3, C=1, decision_function_shape='ovo').fit(X_train, y_train)
sig = svm.SVC(kernel='sigmoid', C=1, decision_function_shape='ovo').fit(X_train, y_train)

# %%
linear_pred = linear.predict(X_test)
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)
sig_pred = sig.predict(X_test)

# %%
poly_accuracy = accuracy_score(y_test, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
lin_accuracy = accuracy_score(y_test, linear_pred)
lin_f1 = f1_score(y_test, linear_pred, average='weighted')
print('Accuracy (linear Kernel): ', "%.2f" % (lin_accuracy*100))
print('F1 (linear Kernel): ', "%.2f" % (lin_f1*100))
sig_accuracy = accuracy_score(y_test, sig_pred)
sig_f1 = f1_score(y_test, sig_pred, average='weighted')
print('Accuracy (sig Kernel): ', "%.2f" % (sig_accuracy*100))
print('F1 (sig Kernel): ', "%.2f" % (sig_f1*100))
# Out:
# Accuracy (Polynomial Kernel):  47.53
# F1 (Polynomial Kernel):  47.91
# Accuracy (RBF Kernel):  41.36
# F1 (RBF Kernel):  39.94
# Accuracy (linear Kernel):  51.85
# F1 (linear Kernel):  51.65
# Accuracy (sig Kernel):  16.67
# F1 (sig Kernel):  4.76
