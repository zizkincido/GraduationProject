# %%
from sklearn import svm
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
df_low_arc = pd.read_csv(r"C:\Users\Aziz\Desktop\Github\CSV\LowMergedFeatured_ARC.csv")
df_low_arc
df_low_arc = df_low_arc.dropna()
like_rate = pd.DataFrame()
like_rate['like_rate_segmentation'] = df_low_arc['like_rate_segmentation.1']
df_low_arc.pop('like_rate_segmentation')
df_low_arc.pop('Unnamed: 0')
df_low_arc.pop('like_rate_segmentation.1')
df = df_low_arc
df['like_rate_segmentation'] = like_rate['like_rate_segmentation']
df
# Out:
#            Hue  Saturation  dominant_hue_1  dominant_sat_1  dominant_val_1  \
# 0    12.335475  136.705829       20.000000       62.637363       35.686275
# 1    90.150061  123.811073      359.347826       37.551020       96.078431
# 2    87.979490   65.092778      211.500000       53.571429       87.843137
# 3    61.950761   59.766570      200.000000        1.630435       72.156863
# 4    91.531847   31.206398      217.500000        3.347280       93.725490
# ..         ...         ...             ...             ...             ...
# 801  60.384576   49.703319       60.000000      100.000000        0.784314
# 802  33.495109   62.682502      197.647059        8.762887       76.078431
# 803  69.265139   10.262431      210.000000        0.840336       93.333333
# 804  92.743739  169.102544      184.000000        5.905512       99.607843
# 805  96.380544  144.372142      192.827586       62.231760       91.372549
#
#      dominant_hue_2  dominant_sat_2  dominant_val_2  dominant_hue_3  \
# 0         23.265306       21.397380       89.803922       22.105263
# 1        358.378378       62.011173       70.196078       54.634146
# 2        213.975904       35.319149       92.156863       40.000000
# 3        170.000000       38.709677       12.156863      240.000000
# 4        213.750000       22.857143       54.901961      207.272727
# ..              ...             ...             ...             ...
# 801      194.482759       12.775330       89.019608      197.142857
# 802       38.571429       29.787234       18.431373       35.000000
# 803      220.384615       49.523810       41.176471      326.666667
# 804      189.073171       96.244131       83.529412      157.500000
# 805      195.505618       37.872340       92.156863      198.000000
#
#      dominant_sat_3  ...  hue_contrast_c3_c4  hue_contrast_c3_c5  \
# 0         80.851064  ...            0.631579            2.894737
# 1        100.000000  ...           54.154146          297.515386
# 2          2.912621  ...           30.000000          171.578947
# 3          4.494382  ...           31.162791            8.571429
# 4         12.359551  ...            1.668449            4.772727
# ..              ...  ...                 ...                 ...
# 801       46.907216  ...          122.142857            3.189369
# 802        4.780876  ...          148.934426            5.000000
# 803        5.421687  ...           97.254902          281.066667
# 804        9.356725  ...           70.500000           22.500000
# 805       20.000000  ...            6.554913            4.386555
#
#      hue_contrast_c4_c5  Number_of_Unique_Hues  Pixels_Belong_To_Dominant_Hue  \
# 0              2.263158                    129                         477100
# 1            351.669533                    157                         380278
# 2            141.578947                    150                         441260
# 3             39.734219                    156                         272857
# 4              6.441176                     98                         224152
# ..                  ...                    ...                            ...
# 801          118.953488                    172                         294812
# 802          153.934426                    134                         125061
# 803          183.811765                    156                         456713
# 804           48.000000                    138                         364129
# 805            2.168359                    173                         478778
#
#      like_rate  michelson_contrast  laplacian  Brightness  \
# 0     0.009483            1.000000   1.717244  101.602062
# 1     0.009501            0.814947   0.553944  153.781059
# 2     0.009505            1.000000  -0.399540  178.920595
# 3     0.009509            1.000000  -0.488165  152.979715
# 4     0.009520            1.000000  -0.033952  164.828605
# ..         ...                 ...        ...         ...
# 801  36.451858            1.000000  -0.494022  117.017349
# 802  30.605805            1.000000  -0.307999  194.753914
# 803  40.406541            0.984436  -0.939174  176.536094
# 804  19.078610            0.992188  -0.397751  177.762270
# 805  31.715092            1.000000   0.063367  196.086878
#
#      like_rate_segmentation
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
# ..                      ...
# 801                       5
# 802                       5
# 803                       5
# 804                       5
# 805                       5
#
# [806 rows x 28 columns]

# %%
X = df.iloc[:, :-1]
y = df.loc[:, 'like_rate_segmentation']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state = 0)

# %%
linear = svm.SVC(kernel='linear', C=1, decision_function_shape='ovo').fit(X_train, y_train)
rbf = svm.SVC(kernel='rbf', gamma=1, C=1, decision_function_shape='ovo').fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=3, C=1, decision_function_shape='ovo').fit(X_train, y_train)
sig = svm.SVC(kernel='sigmoid', C=1, decision_function_shape='ovo').fit(X_train, y_train)

# %%
X

# %%
linear_pred = linear.predict(X_test)
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)
sig_pred = sig.predict(X_test)

# %%
poly_accuracy = accuracy_score(y_test, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
lin_accuracy = accuracy_score(y_test, linear_pred)
lin_f1 = f1_score(y_test, linear_pred, average='weighted')
print('Accuracy (linear Kernel): ', "%.2f" % (lin_accuracy*100))
print('F1 (linear Kernel): ', "%.2f" % (lin_f1*100))
sig_accuracy = accuracy_score(y_test, sig_pred)
sig_f1 = f1_score(y_test, sig_pred, average='weighted')
print('Accuracy (sig Kernel): ', "%.2f" % (sig_accuracy*100))
print('F1 (sig Kernel): ', "%.2f" % (sig_f1*100))

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.multiclass import OneVsOneClassifier
from sklearn.svm import LinearSVC

one = OneVsOneClassifier(LinearSVC(random_state=0)).fit(X, y)
one_predict = one.predict(X)

clf = OneVsRestClassifier(SVC()).fit(X, y)
clf_predict = clf.predict(X)

# %%
accuracy_one = one.score(X, y)
print("“Accuracy One Vs One Classifier:", accuracy_one)
accuracy_clf = clf.score(X, y)
print("“Accuracy One Vs Rest Classifier:", accuracy_clf)
