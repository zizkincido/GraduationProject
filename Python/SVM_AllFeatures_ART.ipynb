# %%
from sklearn import svm
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
column=['pca0','pca1','pca2','pca3','pca4','pca5','pca6',
        'pca7','pca8','pca9','pca10','pca11','pca12','pca13',
        'pca14','pca15','pca16','pca17','pca18','pca19','pca20',
        'pca21','pca22','pca23','pca24','pca25','pca26','pca27',
        'pca28','pca29','pca30','pca31','pca32','pca33','pca34',
        'pca35','pca36','pca37','pca38','pca39','pca40','pca41',
        'pca42','pca43','pca44','pca45','pca46','pca47','pca48','pca49']

# %%
df_lowmid_art = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\ALLFeatures_ART.csv")
df_lowmid_art.drop('like_rate',inplace=True,axis=1)
df_lowmid_art.drop('Unnamed: 0',inplace=True,axis=1)
df_lowmid_art.drop('like_rate_segmentation',inplace=True,axis=1)
like_rate = pd.DataFrame()
like_rate['like_rate_segmentation'] = df_lowmid_art['like_rate_segmentation.1']
df_lowmid_art.pop('like_rate_segmentation.1')
df_lowmid_art.dropna(inplace=True)
pca = PCA(n_components=50) # 2 dimensional PCA
pca.fit(df_lowmid_art)
df_pca = pca.transform(df_lowmid_art) 
df = pd.DataFrame(data=df_pca,columns=column)
df['like_rate_segmentation'] = like_rate['like_rate_segmentation']

# %%
X = df.iloc[:, :-1]
y = df.loc[:, 'like_rate_segmentation']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state = 0)

# %%
linear = svm.SVC(kernel='linear', C=1, decision_function_shape='ovo').fit(X_train, y_train)
rbf = svm.SVC(kernel='rbf', gamma=1, C=1, decision_function_shape='ovo').fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=3, C=1, decision_function_shape='ovo').fit(X_train, y_train)
sig = svm.SVC(kernel='sigmoid', C=1, decision_function_shape='ovo').fit(X_train, y_train)

# %%
linear_pred = linear.predict(X_test)
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)
sig_pred = sig.predict(X_test)

# %%
poly_accuracy = accuracy_score(y_test, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
lin_accuracy = accuracy_score(y_test, linear_pred)
lin_f1 = f1_score(y_test, linear_pred, average='weighted')
print('Accuracy (linear Kernel): ', "%.2f" % (lin_accuracy*100))
print('F1 (linear Kernel): ', "%.2f" % (lin_f1*100))
sig_accuracy = accuracy_score(y_test, sig_pred)
sig_f1 = f1_score(y_test, sig_pred, average='weighted')
print('Accuracy (sig Kernel): ', "%.2f" % (sig_accuracy*100))
print('F1 (sig Kernel): ', "%.2f" % (sig_f1*100))
# Out:
# Accuracy (Polynomial Kernel):  89.17
# F1 (Polynomial Kernel):  88.86
# Accuracy (RBF Kernel):  82.80
# F1 (RBF Kernel):  82.59
# Accuracy (linear Kernel):  100.00
# F1 (linear Kernel):  100.00
# Accuracy (sig Kernel):  96.18
# F1 (sig Kernel):  96.19

# %%
X_train
# Out:
#          pca0      pca1      pca2      pca3      pca4      pca5      pca6  \
# 210 -1.299334  0.078264 -0.221278 -0.293964 -0.200993 -0.122148  0.285051
# 457 -2.099183  1.768652 -0.906942 -1.221604 -0.038641 -0.126170  0.796130
# 499 -1.115291  1.054435 -0.099195 -1.152405 -0.121564 -0.124742  0.241008
# 506 -0.868586  4.820145 -0.390778 -1.557969  0.292129 -1.501168 -0.912356
# 268 -1.070985 -0.512483  0.139354  0.780732 -0.065311  0.275271 -0.033975
# ..        ...       ...       ...       ...       ...       ...       ...
# 763  5.880380  5.778289  5.206763 -0.328646  1.673141 -0.787888 -0.290215
# 192  1.608188 -1.474780  0.100955  0.523614 -1.280509 -0.683164 -0.006170
# 629  1.216648  2.313121 -1.886888 -2.176991  0.191362 -0.748412  0.711484
# 559 -0.629091  1.655571 -1.118645  0.312003 -0.356088  0.298446  0.169585
# 684  1.959740 -0.984864  0.739445 -1.003354  0.495517  0.737800 -0.339845
#
#          pca7      pca8      pca9  ...     pca40     pca41     pca42  \
# 210  0.373053  0.566679 -0.267952  ...  0.201816 -0.323301 -0.093557
# 457 -0.373021  0.288022  0.115326  ...  0.137713 -0.034341 -0.003678
# 499 -0.110152 -0.327319  0.350308  ... -0.089973  0.320675  0.201834
# 506 -0.815221 -1.181957 -0.791203  ...  0.130394 -0.534989 -0.263714
# 268 -0.476765 -0.385129  1.034101  ...  0.026624  0.241985  0.228452
# ..        ...       ...       ...  ...       ...       ...       ...
# 763 -0.670218 -1.049738  0.115191  ... -0.720381 -0.663894 -0.936564
# 192 -0.376088 -0.347706 -0.208965  ...  0.267210  0.194970 -0.129347
# 629 -0.866345 -0.828686 -0.028722  ... -0.157419  0.061418 -0.197120
# 559 -0.751013 -0.199166 -0.129349  ...  0.032310  0.590507  0.251441
# 684  0.296859  0.536549 -0.216109  ... -0.236729 -0.187131  0.171909
#
#         pca43     pca44     pca45     pca46     pca47     pca48     pca49
# 210  0.104130  0.106721 -0.020509  0.105346  0.045471  0.094783 -0.040515
# 457 -0.091330 -0.050419 -0.022261  0.274632 -0.059111  0.140208 -0.293465
# 499  0.116174 -0.087615  0.333009 -0.198514 -0.327892  0.138861  0.252801
# 506 -0.086285  0.599913 -0.351724 -0.304893 -0.112421  0.182456  0.429375
# 268 -0.108381 -0.053996  0.040776 -0.113598 -0.213742  0.142838  0.029583
# ..        ...       ...       ...       ...       ...       ...       ...
# 763 -0.812252  0.112881  0.681482 -0.169026 -0.438356  0.935064 -0.345088
# 192 -0.178645 -0.094235 -0.188084  0.062685 -0.775958 -0.572548 -0.121612
# 629 -0.090140 -0.192912  0.101151  0.332426  0.250362 -0.092875  0.117972
# 559 -0.411988 -0.089603 -0.006286  0.022117  0.186067  0.272629 -0.000639
# 684 -0.753011 -0.107380 -0.054360  0.136891  0.303799 -0.343619  0.384376
#
# [627 rows x 50 columns]

# %%
X_test
# Out:
#          pca0      pca1      pca2      pca3      pca4      pca5      pca6  \
# 693  1.872357 -0.863826 -0.569920 -0.442745 -0.009262  0.484909  0.189904
# 85   1.456211 -1.588964 -0.309445  0.373425 -0.609659 -1.042996  0.058170
# 647  1.706762 -0.729934 -0.541487 -1.201059  0.267047  0.126760 -0.472791
# 392 -2.141232  1.199048 -0.542730 -0.529091 -0.132831 -0.140847  0.366702
# 765  2.853342  2.674137  1.465281  0.464713  0.019779  0.455925  0.817731
# ..        ...       ...       ...       ...       ...       ...       ...
# 76   0.601029 -1.516517 -0.267276  0.405069  1.000395 -0.178599  0.402426
# 64  -0.161157 -1.168310  0.165984  1.155201  0.086508 -0.932070 -0.179397
# 623 -0.087978  0.454808 -0.004044 -1.183257 -0.589158  0.014489 -0.270466
# 52  -0.241889 -1.039751  0.097282  0.745803  0.056002 -0.123043 -0.044748
# 720  0.972340 -0.601194 -0.713872  0.021201  0.795502  1.073429  0.062462
#
#          pca7      pca8      pca9  ...     pca40     pca41     pca42  \
# 693 -0.632505  0.538640  0.360526  ...  0.170724 -0.444547 -0.155796
# 85   0.046470  0.192994 -0.320157  ...  0.299897  0.124449 -0.240942
# 647  0.619022  0.371245  0.047759  ...  0.112183 -0.122418  0.208328
# 392  0.407006  0.159421 -0.349770  ...  0.074509  0.196281  0.418726
# 765 -0.270119 -0.147503  0.605739  ...  0.094239  0.697689 -0.749546
# ..        ...       ...       ...  ...       ...       ...       ...
# 76  -0.194348 -0.486296 -0.046412  ... -0.056025 -0.055892 -0.084133
# 64  -0.238809  0.468557  0.190834  ... -0.134108  0.178659 -0.134728
# 623  0.133910  0.525550 -0.181301  ...  0.259551 -0.221386 -0.160372
# 52  -0.071800 -0.072718 -0.062950  ...  0.093809  0.373516 -0.025259
# 720  0.345962 -0.001184 -0.178688  ... -0.064168 -0.052284 -0.397955
#
#         pca43     pca44     pca45     pca46     pca47     pca48     pca49
# 693  0.142471  0.248818  0.077772  0.040210 -0.033610 -0.033561 -0.079146
# 85  -0.174721 -0.092937  0.227244 -0.015952 -0.079941 -0.265737 -0.583433
# 647  0.004599 -0.031316 -0.052083 -0.277585 -0.133339  0.007274  0.009518
# 392 -0.350600 -0.013044 -0.019731 -0.129303  0.208070  0.120937 -0.068375
# 765 -0.770228  0.661071 -0.591133  0.228348 -0.044127  0.584171 -0.218337
# ..        ...       ...       ...       ...       ...       ...       ...
# 76  -0.059738  0.096377  0.000395  0.124388  0.048684 -0.109791  0.114846
# 64  -0.042259 -0.193784  0.017142 -0.078937 -0.056342  0.045840  0.000291
# 623 -0.252961  0.464471 -0.303164  0.032168  0.319736 -0.227280 -0.062146
# 52  -0.031381 -0.134296 -0.004358 -0.270982 -0.028366 -0.230662 -0.196051
# 720  0.190574 -0.047714  0.028081 -0.578404  0.149237  0.287693  0.692000
#
# [157 rows x 50 columns]
