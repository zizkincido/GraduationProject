# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Average_hsv_arc.csv")
df.pop('Unnamed: 0')
df.head(5)
i=0
j=0
for j in range(2):
    for i in range(807):
        normalizer = (df.iloc[i,j]-df.iloc[:,j].min())/(df.iloc[:,j].max()-df.iloc[:,j].min())
        df.iloc[i,j] = normalizer

# %%
df2 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\color_palette_and_hue_contrast_arc.csv")
df2.head(1)
i=0
j=0
for j in range(20):
    for i in range(807):
        normalizer = (df2.iloc[i,j]-df2.iloc[:,j].min())/(df2.iloc[:,j].max()-df2.iloc[:,j].min())
        df2.iloc[i,j] = normalizer
# Out:
# <ipython-input-2-4d6c71a61891>:7: RuntimeWarning: invalid value encountered in double_scalars
#   normalizer = (df2.iloc[i,j]-df2.iloc[:,j].min())/(df2.iloc[:,j].max()-df2.iloc[:,j].min())

# %%
df4 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Dominant_Unique_Hue_arc.csv")
df4.pop('Unnamed: 0')
df4.head(1)
i=0
j=0
for j in range(3):
    for i in range(807):
        normalizer = (df4.iloc[i,j]-df4.iloc[:,j].min())/(df4.iloc[:,j].max()-df4.iloc[:,j].min())
        df4.iloc[i,j] = normalizer

# %%
df5 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Entropy_ARC_Ters.csv")
df5.pop('Unnamed: 0')
df5.head(1)
i=0
j=0
for j in range(1):
    for i in range(807):
        normalizer = (df5.iloc[i,j]-df5.iloc[:,j].min())/(df5.iloc[:,j].max()-df5.iloc[:,j].min())
        df5.iloc[i,j] = normalizer

# %%
df6 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\like_rate_segmentation_by_date_arc.csv")
df6.head(1)
# Out:
#    like_rate_segmentation
# 0                       1

# %%
df7 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\michelson_arc.csv")
df7.head(1)
i=0
j=0
for j in range(1):
    for i in range(807):
        normalizer = (df7.iloc[i,j]-df7.iloc[:,j].min())/(df7.iloc[:,j].max()-df7.iloc[:,j].min())
        df7.iloc[i,j] = normalizer

# %%
df8 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Wmc_ARC_Ters.csv")
df8.pop('Unnamed: 0')
df8.head(1)
# Out:
#    Wmc  Wmc2  Wmc3  Wmc4  Wmc5  Wmc6  Wmc7  Wmc8  Wmc9  Wmc10  ...  Wmc141  \
# 0    2     2     0     1     2     3     4     6     5     10  ...       5
#
#    Wmc142  Wmc143  Wmc144  Wmc145  Wmc146  Wmc147  Wmc148  Wmc149  Wmc150
# 0       3       0       0       0       0       0       0       0       1
#
# [1 rows x 150 columns]

# %%
i=0
j=0
for j in range(150):
    for i in range(807):
        normalizer = (df8.iloc[i,j]-df8.iloc[:,j].min())/(df8.iloc[:,j].max()-df8.iloc[:,j].min())
        df8.iloc[i,j] = normalizer

# %%
df8
# Out:
#           Wmc      Wmc2      Wmc3      Wmc4      Wmc5      Wmc6      Wmc7  \
# 0    0.062500  0.125000  0.000000  0.023256  0.039216  0.051724  0.053333
# 1    0.055351  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    0.055749  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3    0.114765  0.062500  0.117647  0.116279  0.058824  0.086207  0.040000
# 4    0.114765  0.000000  0.000000  0.000000  0.019608  0.000000  0.013333
# ..        ...       ...       ...       ...       ...       ...       ...
# 802  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 803  0.485769  0.333333  0.250000  0.250000  0.000000  0.083333  0.071429
# 804  0.485769  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 805  1.000000  0.333333  0.750000  0.500000  0.000000  0.000000  0.071429
# 806  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
#
#          Wmc8      Wmc9     Wmc10  ...    Wmc141    Wmc142    Wmc143  \
# ...

# %%
df9 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\laplacian_ARC_pca.csv")
df9.pop('Unnamed: 0')
df9.head(1)
i=0
j=0
for j in range(50):
    for i in range(807):
        normalizer = (df9.iloc[i,j]-df9.iloc[:,j].min())/(df9.iloc[:,j].max()-df9.iloc[:,j].min())
        df9.iloc[i,j] = normalizer

# %%
df9
# Out:
#      laplacian0  laplacian1  laplacian2  laplacian3  laplacian4  laplacian5  \
# 0      0.151292    0.378373    0.419472    0.324947    0.458675    0.332176
# 1      0.541472    0.459604    0.303084    0.322484    0.496809    0.327973
# 2      0.231057    0.336895    0.426351    0.271510    0.382975    0.279780
# 3      0.255001    0.508661    0.507274    0.330561    0.456068    0.414229
# 4      0.334579    0.394682    0.389931    0.262621    0.433297    0.425829
# ..          ...         ...         ...         ...         ...         ...
# 802    0.000000    0.129039    0.000000    0.054065    0.000000    0.330753
# 803    0.000000    0.095553    0.223173    0.000000    0.034008    0.460502
# 804    1.000000    1.000000    0.000000    0.000000    0.101798    0.142974
# 805    0.000000    0.138816    0.151220    0.217819    0.292391    0.476893
# 806    0.664068    0.000000    0.126399    0.063364    0.035265    0.000000
#
# ...

# %%
df10 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\brightness_ARC.csv")
df10.pop('Unnamed: 0')
df10.head(1)
i=0
j=0
for j in range(1):
    for i in range(807):
        normalizer = (df10.iloc[i,j]-df10.iloc[:,j].min())/(df10.iloc[:,j].max()-df10.iloc[:,j].min())
        df10.iloc[i,j] = normalizer

# %%
df11 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Dtvarc_ters_normal_updated.csv")
df11.pop('Unnamed: 0')
df11.head(1)
i=0
j=0
for j in range(12):
    for i in range(807):
        normalizer = (df11.iloc[i,j]-df11.iloc[:,j].min())/(df11.iloc[:,j].max()-df11.iloc[:,j].min())
        df11.iloc[i,j] = normalizer

# %%
df11
# Out:
#       DTVnorm  DTVnorm2  DTVnorm3  DTVnorm4  DTVnorm5  DTVnorm6  DTVnorm7  \
# 0    0.126229  0.120996  0.118913  0.118114  0.118105  0.119525  0.124714
# 1    0.039443  0.037864  0.036822  0.036121  0.035722  0.035765  0.036825
# 2    0.039982  0.039254  0.039756  0.040898  0.042489  0.044489  0.046747
# 3    0.198983  0.188640  0.177794  0.167443  0.158393  0.152336  0.152643
# 4    0.122500  0.114270  0.106403  0.098355  0.090338  0.083915  0.084423
# ..        ...       ...       ...       ...       ...       ...       ...
# 802  0.089041  0.085480  0.083790  0.082520  0.081372  0.080956  0.083567
# 803  0.046999  0.049515  0.057022  0.065838  0.074977  0.083986  0.091286
# 804  0.008684  0.008588  0.008699  0.008908  0.009174  0.009489  0.009842
# 805  0.047590  0.046399  0.047002  0.048002  0.049081  0.050447  0.052955
# 806  0.036665  0.036391  0.037473  0.039034  0.040839  0.042867  0.045015
#
#      DTVnorm8  DTVnorm9  DTVnorm10  DTVnorm11  DTVnorm12
# ...

# %%
result = pd.concat([df,df2,df4,df5,df6,df7,df8,df9,df10,df11], axis=1)
low1 = pd.concat([df,df2,df4,df6,df7,df9,df10], axis=1)

# %%
result
# Out:
#           Hue  Saturation  dominant_hue_1  dominant_sat_1  dominant_val_1  \
# 0    0.082535    0.600846        0.055656        0.626374        0.356863
# 1    0.603184    0.544172        1.000000        0.375510        0.960784
# 2    0.588661    0.286094        0.588987        0.535714        0.878431
# 3    0.414506    0.262685        0.556962        0.016304        0.721569
# 4    0.612429    0.137158        0.605696        0.033473        0.937255
# ..        ...         ...             ...             ...             ...
# 802  0.347530    0.370677        0.941176        0.140811        0.763780
# 803  0.718663    0.060688        1.000000        0.013503        0.937008
# 804  0.962266    1.000000        0.954220        0.094895        1.000000
# 805  1.000000    1.000000        1.000000        1.000000        0.947154
# 806  1.000000    1.000000        1.000000        0.406504        1.000000
#
#      dominant_hue_2  dominant_sat_2  dominant_val_2  dominant_hue_3  \
# ...

# %%
df = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Average_hsv_art.csv")
df.pop('Unnamed: 0')
i=0
j=0
for j in range(2):
    for i in range(784):
        normalizer = (df.iloc[i,j]-df.iloc[:,j].min())/(df.iloc[:,j].max()-df.iloc[:,j].min())
        df.iloc[i,j] = normalizer
df2 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\color_palette_and_hue_contrast_art.csv")
i=0
j=0
for j in range(20):
    for i in range(784):
        normalizer = (df2.iloc[i,j]-df2.iloc[:,j].min())/(df2.iloc[:,j].max()-df2.iloc[:,j].min())
        df2.iloc[i,j] = normalizer
df4 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Dominant_Unique_Hue_art.csv")
df4.pop('Unnamed: 0')
i=0
j=0
for j in range(3):
    for i in range(784):
        normalizer = (df4.iloc[i,j]-df4.iloc[:,j].min())/(df4.iloc[:,j].max()-df4.iloc[:,j].min())
        df4.iloc[i,j] = normalizer
df5 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Entropy_ART_Ters.csv")
df5.pop('Unnamed: 0')
i=0
j=0
for j in range(1):
    for i in range(784):
        normalizer = (df5.iloc[i,j]-df5.iloc[:,j].min())/(df5.iloc[:,j].max()-df5.iloc[:,j].min())
        df5.iloc[i,j] = normalizer
df6 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\like_rate_segmentation_by_date_art.csv")

df7 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\michelson_art.csv")
i=0
j=0
for j in range(1):
    for i in range(784):
        normalizer = (df7.iloc[i,j]-df7.iloc[:,j].min())/(df7.iloc[:,j].max()-df7.iloc[:,j].min())
        df7.iloc[i,j] = normalizer
df8 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Wmc_ART_Ters.csv")
df8.pop('Unnamed: 0')
i=0
j=0
for j in range(150):
    for i in range(784):
        normalizer = (df8.iloc[i,j]-df8.iloc[:,j].min())/(df8.iloc[:,j].max()-df8.iloc[:,j].min())
        df8.iloc[i,j] = normalizer
df9 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\laplacian_ART_pca.csv")
df9.pop('Unnamed: 0')
i=0
j=0
for j in range(50):
    for i in range(784):
        normalizer = (df9.iloc[i,j]-df9.iloc[:,j].min())/(df9.iloc[:,j].max()-df9.iloc[:,j].min())
        df9.iloc[i,j] = normalizer
df10 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\brightness_ART.csv")
df10.pop('Unnamed: 0')
i=0
j=0
for j in range(1):
    for i in range(784):
        normalizer = (df10.iloc[i,j]-df10.iloc[:,j].min())/(df10.iloc[:,j].max()-df10.iloc[:,j].min())
        df10.iloc[i,j] = normalizer
df11 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Dtvart_ters_normal_updated.csv")
df11.pop('Unnamed: 0')
i=0
j=0
for j in range(12):
    for i in range(784):
        normalizer = (df11.iloc[i,j]-df11.iloc[:,j].min())/(df11.iloc[:,j].max()-df11.iloc[:,j].min())
        df11.iloc[i,j] = normalizer
result2 = pd.concat([df,df2,df4,df5,df6,df7,df8,df9,df10,df11], axis=1)
result2.pop('id')
low2 = pd.concat([df,df2,df4,df6,df7,df9,df10], axis=1)

# %%
result2
# Out:
#           Hue  Saturation  dominant_hue_1  dominant_sat_1  dominant_val_1  \
# 0    0.149434    0.690954        0.085611        0.783505        0.380392
# 1    0.414926    0.586384        0.015166        0.683230        0.631373
# 2    0.249934    0.488923        0.109303        0.308511        0.368627
# 3    0.694969    0.536675        0.784725        0.145161        0.729412
# 4    0.475263    0.624479        0.000000        0.467005        0.772549
# ..        ...         ...             ...             ...             ...
# 779  1.000000    1.000000        1.000000        1.000000        1.000000
# 780  0.732462    0.516319        1.000000        0.231407        1.000000
# 781  0.675118    0.468332        0.171429        0.087846        0.415459
# 782  1.000000    1.000000        1.000000        0.239358        0.975845
# 783  1.000000    1.000000        1.000000        1.000000        1.000000
#
#      dominant_hue_2  dominant_sat_2  dominant_val_2  dominant_hue_3  \
# ...

# %%
result.to_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\LowAndMidMergedFeatures_ARC.csv")
result2.to_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\LowAndMidMergedFeatured_ART.csv")
low1.to_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\LowMergedFeatured_ARC.csv")
low2.to_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\LowMergedFeatured_ART.csv")

# %%
#HAMMER TIME(SALIENT)

# %%
df = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Average_hsv_arc_cropped.csv")
df.pop('Unnamed: 0')
df.pop('like_rate')
df
# Out:
#           Hue  Saturation
# 0    0.149502    0.682825
# 1    0.422565    0.659105
# 2    0.242421    0.543924
# 3    0.611565    0.697291
# 4    0.527048    0.694404
# ..        ...         ...
# 779  0.784653    0.751156
# 780  0.345446    0.367558
# 781  0.387867    0.389740
# 782  0.624226    0.660277
# 783  0.388908    0.487486
#
# [784 rows x 2 columns]

# %%
df2 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\color_palette_and_hue_contrast_arc_cropped.csv")
df2.head(1)
df2.pop('id')
i=0
j=0
for j in range(20):
    for i in range(807):
        normalizer = (df2.iloc[i,j]-df2.iloc[:,j].min())/(df2.iloc[:,j].max()-df2.iloc[:,j].min())
        df2.iloc[i,j] = normalizer
df2
# Out:
# <ipython-input-22-84bfe5eedf78>:8: RuntimeWarning: invalid value encountered in double_scalars
#   normalizer = (df2.iloc[i,j]-df2.iloc[:,j].min())/(df2.iloc[:,j].max()-df2.iloc[:,j].min())
#      dominant_hue_1  dominant_sat_1  dominant_val_1  dominant_hue_2  \
# 0          0.069091        0.194093        0.929412        0.070469
# 1          0.188598        1.000000        0.984314        0.000000
# 2          0.191169        0.030172        0.909804        0.167364
# 3          0.557576        0.016304        0.721569        0.476344
# 4          0.577851        0.123596        0.698039        0.564854
# ..              ...             ...             ...             ...
# 802        0.108959        0.764107        0.192623        0.903409
# 803        1.000000        0.143308        0.733607        1.000000
# 804        0.966000        0.932806        0.225410        0.974853
# 805        1.000000        1.000000        0.967213        1.000000
# ...

# %%
df4 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Dominant_Unique_Hue_arc_cropped.csv")
df4.pop('Unnamed: 0')
df4.pop('like_rate')
df4.head(1)
i=0
j=0
for j in range(2):
    for i in range(807):
        normalizer = (df4.iloc[i,j]-df4.iloc[:,j].min())/(df4.iloc[:,j].max()-df4.iloc[:,j].min())
        df4.iloc[i,j] = normalizer
df4
# Out:
#      Number_of_Unique_Hues  Pixels_Belong_To_Dominant_Hue
# 0                 0.711111                       0.114610
# 1                 0.839147                       0.112375
# 2                 0.822507                       0.066364
# 3                 0.861334                       0.112929
# 4                 0.539628                       0.092818
# ..                     ...                            ...
# 802               0.774563                       0.652229
# 803               0.901732                       0.491180
# 804               0.797684                       0.609268
# 805               1.000000                       1.000000
# 806               1.000000                       1.000000
#
# [807 rows x 2 columns]

# %%
df5 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Entropy_ARC_Cropped_ters.csv")
df5.pop('Unnamed: 0')
df5.head(1)
i=0
j=0
for j in range(1):
    for i in range(807):
        normalizer = (df5.iloc[i,j]-df5.iloc[:,j].min())/(df5.iloc[:,j].max()-df5.iloc[:,j].min())
        df5.iloc[i,j] = normalizer
df5
# Out:
#       Entropy
# 0    0.944094
# 1    0.936349
# 2    0.861743
# 3    0.948257
# 4    0.947135
# ..        ...
# 802  1.000000
# 803  0.971008
# 804  0.796230
# 805  0.980362
# 806  1.000000
#
# [807 rows x 1 columns]

# %%
df6 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\like_rate_segmentation_by_date_arc.csv")
df6.head(1)
# Out:
#    like_rate_segmentation
# 0                       1

# %%
df7 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\michelson_arc_cropped.csv")
df7.head(1)
i=0
j=0
for j in range(1):
    for i in range(807):
        normalizer = (df7.iloc[i,j]-df7.iloc[:,j].min())/(df7.iloc[:,j].max()-df7.iloc[:,j].min())
        df7.iloc[i,j] = normalizer
df7
# Out:
#      michelson_contrast
# 0              1.000000
# 1              0.760009
# 2              1.000000
# 3              1.000000
# 4              1.000000
# ..                  ...
# 802            1.000000
# 803            0.983342
# 804            0.991638
# 805            1.000000
# 806            1.000000
#
# [807 rows x 1 columns]

# %%
df8 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\WmcArc_Cropped_Ters.csv")
df8.pop('Unnamed: 0')
df8.head(1)
i=0
j=0
for j in range(150):
    for i in range(807):
        normalizer = (df8.iloc[i,j]-df8.iloc[:,j].min())/(df8.iloc[:,j].max()-df8.iloc[:,j].min())
        df8.iloc[i,j] = normalizer
df8
# Out:
#           Wmc      Wmc2      Wmc3      Wmc4      Wmc5      Wmc6      Wmc7  \
# 0    0.050000  0.125000  0.000000  0.023256  0.039216  0.051724  0.053333
# 1    0.045346  0.000000  0.000000  0.023256  0.000000  0.000000  0.013333
# 2    0.045558  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3    0.093280  0.062500  0.117647  0.116279  0.058824  0.086207  0.040000
# 4    0.093280  0.000000  0.000000  0.000000  0.019608  0.000000  0.013333
# ..        ...       ...       ...       ...       ...       ...       ...
# 802  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 803  0.488400  0.333333  0.250000  0.250000  0.000000  0.083333  0.071429
# 804  0.488400  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 805  1.000000  0.333333  0.750000  0.500000  0.000000  0.000000  0.071429
# 806  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
#
#          Wmc8      Wmc9     Wmc10  ...    Wmc141    Wmc142    Wmc143  \
# ...

# %%
df9 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\laplacian_arc_cropped_pca.csv")
df9.pop('Unnamed: 0')
df9.head(1)
i=0
j=0
for j in range(50):
    for i in range(807):
        normalizer = (df9.iloc[i,j]-df9.iloc[:,j].min())/(df9.iloc[:,j].max()-df9.iloc[:,j].min())
        df9.iloc[i,j] = normalizer
df9
# Out:
#      laplacian0  laplacian1  laplacian2  laplacian3  laplacian4  laplacian5  \
# 0      0.079703    0.481665    0.088512    0.421818    0.427173    0.487475
# 1      0.162002    0.498317    0.299464    0.590131    0.386365    0.381565
# 2      0.077107    0.485011    0.103276    0.373255    0.277404    0.491134
# 3      0.186822    0.435923    0.078501    0.444998    0.414549    0.485518
# 4      0.161074    0.463387    0.100344    0.484504    0.442366    0.477387
# ..          ...         ...         ...         ...         ...         ...
# 802    0.000000    0.186579    0.000000    0.000000    0.217637    0.406861
# 803    0.000000    0.412754    0.090636    0.085951    0.000000    0.450351
# 804    1.000000    0.480600    0.504050    0.473404    0.270370    0.000000
# 805    0.422385    0.000000    0.278278    0.000000    0.000000    0.000000
# 806    0.244472    0.198674    0.000000    0.027216    0.074629    0.220969
#
# ...

# %%
df10 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\brightness_ARC_cropped_ters.csv")
df10.pop('Unnamed: 0')
df10.head(1)
i=0
j=0
for j in range(1):
    for i in range(807):
        normalizer = (df10.iloc[i,j]-df10.iloc[:,j].min())/(df10.iloc[:,j].max()-df10.iloc[:,j].min())
        df10.iloc[i,j] = normalizer
df10
# Out:
#      Brightness
# 0      0.554541
# 1      0.675416
# 2      0.731171
# 3      0.651039
# 4      0.701607
# ..          ...
# 802    0.647134
# 803    0.791462
# 804    1.000000
# 805    1.000000
# 806    1.000000
#
# [807 rows x 1 columns]

# %%
df11 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Dtv_ARC_Cropped_Ters_Normal.csv")
df11.pop('Unnamed: 0')
df11.head(1)
i=0
j=0
for j in range(12):
    for i in range(807):
        normalizer = (df11.iloc[i,j]-df11.iloc[:,j].min())/(df11.iloc[:,j].max()-df11.iloc[:,j].min())
        df11.iloc[i,j] = normalizer
df11
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.117010  0.111420  0.108441  0.106481  0.105138  0.105177  0.109281
# 1    0.033167  0.031865  0.031012  0.030370  0.029899  0.029768  0.030588
# 2    0.023558  0.023113  0.023322  0.023863  0.024636  0.025670  0.026941
# 3    0.201243  0.190921  0.180199  0.169975  0.161029  0.155077  0.155545
# 4    0.125057  0.116836  0.109089  0.101165  0.093253  0.086941  0.087626
# ..        ...       ...       ...       ...       ...       ...       ...
# 802  0.086450  0.083015  0.081366  0.080104  0.078942  0.078501  0.081027
# 803  0.044866  0.047030  0.054112  0.062493  0.071207  0.079861  0.087040
# 804  0.007906  0.007925  0.008198  0.008567  0.008974  0.009427  0.009892
# 805  0.048816  0.047712  0.048517  0.049728  0.051005  0.052570  0.055276
# 806  0.036468  0.036306  0.037587  0.039342  0.041310  0.043489  0.045779
#
#             7         8         9        10        11
# ...

# %%
resultsalience = pd.concat([df,df2,df4,df5,df6,df7,df8,df9,df10,df11], axis=1)

# %%
df = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Average_hsv_art_cropped.csv")
df.pop('Unnamed: 0')
for j in range(2):
    for i in range(784):
        normalizer = (df.iloc[i,j]-df.iloc[:,j].min())/(df.iloc[:,j].max()-df.iloc[:,j].min())
        df.iloc[i,j] = normalizer
df
# Out:
#           Hue  Saturation
# 0    0.119020    0.681961
# 1    0.422086    0.658176
# 2    0.241792    0.542681
# 3    0.611243    0.696558
# 4    0.526656    0.693664
# ..        ...         ...
# 779  1.000000    1.000000
# 780  0.553211    0.556663
# 781  0.621197    0.590260
# 782  1.000000    1.000000
# 783  1.000000    1.000000
#
# [784 rows x 2 columns]

# %%
df2 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\color_palette_and_hue_contrast_art_cropped.csv")
df2.head(1)
df2.pop('id')
df2.pop('like_rate_segmentation')
i=0
j=0
for j in range(19):
    for i in range(784):
        normalizer = (df2.iloc[i,j]-df2.iloc[:,j].min())/(df2.iloc[:,j].max()-df2.iloc[:,j].min())
        df2.iloc[i,j] = normalizer
df2
# Out:
#      dominant_hue_1  dominant_sat_1  dominant_val_1  dominant_hue_2  \
# 0          0.111277        0.590674        0.756863        0.066274
# 1          0.014410        0.794286        0.686275        0.563046
# 2          0.637312        0.297297        0.145098        0.055609
# 3          0.969035        0.620690        0.682353        0.233560
# 4          1.000000        0.530806        0.827451        0.839944
# ..              ...             ...             ...             ...
# 779        0.199584        0.406593        0.439614        0.032360
# 780        0.205128        1.000000        0.028986        0.251690
# 781        1.000000        0.722356        0.169082        1.000000
# 782        1.000000        1.000000        1.000000        1.000000
# 783        1.000000        1.000000        1.000000        1.000000
#
#      dominant_sat_2  dominant_val_2  dominant_hue_3  dominant_sat_3  \
# 0          0.869048        0.658824        0.091335        0.198113
# ...

# %%
df4 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Dominant_Unique_Hue_art_cropped.csv")
df4.pop('Unnamed: 0')
df4.pop('like_rate')
df4.head(1)
i=0
j=0
for j in range(2):
    for i in range(784):
        normalizer = (df4.iloc[i,j]-df4.iloc[:,j].min())/(df4.iloc[:,j].max()-df4.iloc[:,j].min())
        df4.iloc[i,j] = normalizer
df4
# Out:
#      Number_of_Unique_Hues  Pixels_Belong_To_Dominant_Hue
# 0                 1.000000                       0.037420
# 1                 1.000000                       0.066282
# 2                 1.000000                       0.166256
# 3                 1.000000                       0.092114
# 4                 1.000000                       0.133709
# ..                     ...                            ...
# 779               1.000000                       0.301252
# 780               0.994473                       0.525172
# 781               0.977891                       1.000000
# 782               0.988946                       0.934594
# 783               1.000000                       1.000000
#
# [784 rows x 2 columns]

# %%
df5 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Entropy_ART_Cropped_ters.csv")
df5.pop('Unnamed: 0')
df5.head(1)
i=0
j=0
for j in range(1):
    for i in range(784):
        normalizer = (df5.iloc[i,j]-df5.iloc[:,j].min())/(df5.iloc[:,j].max()-df5.iloc[:,j].min())
        df5.iloc[i,j] = normalizer
df5
# Out:
#       Entropy
# 0    0.926942
# 1    0.983739
# 2    0.947700
# 3    0.951675
# 4    0.934169
# ..        ...
# 779  0.956524
# 780  1.000000
# 781  1.000000
# 782  0.992869
# 783  1.000000
#
# [784 rows x 1 columns]

# %%
df6 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\like_rate_segmentation_by_date_art.csv")
df6.head(1)
# Out:
#    like_rate_segmentation
# 0                       2

# %%
df7 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\michelson_art_cropped.csv")
df7.head(1)
i=0
j=0
for j in range(1):
    for i in range(784):
        normalizer = (df7.iloc[i,j]-df7.iloc[:,j].min())/(df7.iloc[:,j].max()-df7.iloc[:,j].min())
        df7.iloc[i,j] = normalizer
df7
# Out:
#      michelson_contrast
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
# ..                  ...
# 779                 1.0
# 780                 1.0
# 781                 1.0
# 782                 1.0
# 783                 1.0
#
# [784 rows x 1 columns]

# %%
df8 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\WmcArt_Cropped_Ters.csv")
df8.pop('Unnamed: 0')
df8.head(1)
i=0
j=0
for j in range(150):
    for i in range(784):
        normalizer = (df8.iloc[i,j]-df8.iloc[:,j].min())/(df8.iloc[:,j].max()-df8.iloc[:,j].min())
        df8.iloc[i,j] = normalizer
df8
# Out:
#           Wmc     Wmc2      Wmc3  Wmc4      Wmc5      Wmc6      Wmc7     Wmc8  \
# 0    0.000000  0.00159  0.000000   0.0  0.000000  0.000000  0.000000  0.00000
# 1    0.005650  0.00000  0.000000   0.0  0.000000  0.000000  0.001946  0.00232
# 2    0.005650  0.00000  0.005882   0.0  0.000000  0.013605  0.000000  0.00000
# 3    0.005650  0.00000  0.000000   0.0  0.008197  0.000000  0.000000  0.00000
# 4    0.011299  0.00000  0.000000   0.0  0.008197  0.000000  0.000000  0.00232
# ..        ...      ...       ...   ...       ...       ...       ...      ...
# 779  0.500000  0.00000  0.000000   0.0  0.000000  0.000000  0.000000  0.00000
# 780  0.500000  0.00000  0.000000   0.0  0.000000  0.000000  0.000000  1.00000
# 781  0.500000  0.00000  0.000000   1.0  1.000000  1.000000  1.000000  1.00000
# 782  1.000000  1.00000  0.000000   0.0  0.000000  1.000000  0.000000  0.00000
# 783  1.000000  0.00000  1.000000   1.0  0.000000  0.000000  0.000000  0.00000
#
# ...

# %%
df9 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\laplacian_art_cropped_pca.csv")
df9.pop('Unnamed: 0')
df9.head(1)
i=0
j=0
for j in range(50):
    for i in range(784):
        normalizer = (df9.iloc[i,j]-df9.iloc[:,j].min())/(df9.iloc[:,j].max()-df9.iloc[:,j].min())
        df9.iloc[i,j] = normalizer
df9
# Out:
#      laplacian0  laplacian1  laplacian2  laplacian3  laplacian4  laplacian5  \
# 0      0.139740    0.029963    0.202141    0.060967    0.286334    0.096043
# 1      0.140884    0.027346    0.202666    0.064855    0.286487    0.110230
# 2      0.151444    0.049271    0.223129    0.097096    0.278020    0.094537
# 3      0.141187    0.031193    0.203099    0.057843    0.287358    0.083085
# 4      0.162394    0.050185    0.206994    0.082389    0.292659    0.092594
# ..          ...         ...         ...         ...         ...         ...
# 779    0.451539    0.001828    0.602327    0.653672    0.000000    0.000000
# 780    0.343370    0.014327    0.498784    0.157092    0.096526    0.024888
# 781    0.419601    0.000000    0.504112    0.310707    0.325201    0.000000
# 782    0.541141    0.000000    0.492702    0.262071    0.000000    0.030187
# 783    0.000000    1.000000    0.000000    0.000000    0.023050    0.000000
#
# ...

# %%
df10 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\brightness_ART_cropped_ters.csv")
df10.pop('Unnamed: 0')
df10.head(1)
i=0
j=0
for j in range(1):
    for i in range(784):
        normalizer = (df10.iloc[i,j]-df10.iloc[:,j].min())/(df10.iloc[:,j].max()-df10.iloc[:,j].min())
        df10.iloc[i,j] = normalizer
df10
# Out:
#      Brightness
# 0      0.409685
# 1      0.484751
# 2      0.589001
# 3      0.448235
# 4      0.490606
# ..          ...
# 779    0.603860
# 780    0.874038
# 781    0.865210
# 782    0.660240
# 783    1.000000
#
# [784 rows x 1 columns]

# %%
df11 = pd.read_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\Dtv_ART_Cropped_Ters_Normal.csv")
df11.pop('Unnamed: 0')
df11.head(1)
i=0
j=0
for j in range(12):
    for i in range(784):
        normalizer = (df11.iloc[i,j]-df11.iloc[:,j].min())/(df11.iloc[:,j].max()-df11.iloc[:,j].min())
        df11.iloc[i,j] = normalizer
df11
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.106043  0.109397  0.111031  0.113236  0.115760  0.118344  0.120770
# 1    0.261796  0.264854  0.262247  0.260278  0.258643  0.258070  0.261258
# 2    0.205307  0.209514  0.209623  0.210594  0.212162  0.214316  0.217546
# 3    0.174345  0.178922  0.179036  0.179467  0.180165  0.181049  0.182148
# 4    0.198754  0.202761  0.202636  0.203624  0.205596  0.208431  0.211990
# ..        ...       ...       ...       ...       ...       ...       ...
# 779  0.041004  0.042090  0.042559  0.043554  0.045028  0.046740  0.048199
# 780  0.132992  0.134990  0.137146  0.142298  0.149794  0.158743  0.167304
# 781  0.161686  0.163446  0.165115  0.170121  0.177852  0.187656  0.197854
# 782  0.103240  0.103667  0.103438  0.105044  0.108222  0.112776  0.118175
# 783  0.127005  0.130444  0.132733  0.136171  0.140226  0.144595  0.148968
#
#             7         8         9        10        11
# ...

# %%
result2salience = pd.concat([df,df2,df4,df5,df6,df7,df8,df9,df10,df11], axis=1)
result2salience
# Out:
#           Hue  Saturation  dominant_hue_1  dominant_sat_1  dominant_val_1  \
# 0    0.119020    0.681961        0.111277        0.590674        0.756863
# 1    0.422086    0.658176        0.014410        0.794286        0.686275
# 2    0.241792    0.542681        0.637312        0.297297        0.145098
# 3    0.611243    0.696558        0.969035        0.620690        0.682353
# 4    0.526656    0.693664        1.000000        0.530806        0.827451
# ..        ...         ...             ...             ...             ...
# 779  1.000000    1.000000        0.199584        0.406593        0.439614
# 780  0.553211    0.556663        0.205128        1.000000        0.028986
# 781  0.621197    0.590260        1.000000        0.722356        0.169082
# 782  1.000000    1.000000        1.000000        1.000000        1.000000
# 783  1.000000    1.000000        1.000000        1.000000        1.000000
#
#      dominant_hue_2  dominant_sat_2  dominant_val_2  dominant_hue_3  \
# ...

# %%
resultsalience.to_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\LowAndMidMergedFeatures_ARC_salience.csv")
result2salience.to_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\LowAndMidMergedFeatured_ART_salience.csv")

# %%
print(result.columns.tolist())
# Out:
# ['Hue', 'Saturation', 'dominant_hue_1', 'dominant_sat_1', 'dominant_val_1', 'dominant_hue_2', 'dominant_sat_2', 'dominant_val_2', 'dominant_hue_3', 'dominant_sat_3', 'dominant_val_3', 'hue_contrast_c1_c2', 'hue_contrast_c1_c3', 'hue_contrast_c1_c4', 'hue_contrast_c1_c5', 'hue_contrast_c2_c3', 'hue_contrast_c2_c4', 'hue_contrast_c2_c5', 'hue_contrast_c3_c4', 'hue_contrast_c3_c5', 'hue_contrast_c4_c5', 'Number_of_Unique_Hues', 'Pixels_Belong_To_Dominant_Hue', 'like_rate', 'Entropy', 'michelson_contrast', 'Wmc', 'Wmc2', 'Wmc3', 'Wmc4', 'Wmc5', 'Wmc6', 'Wmc7', 'Wmc8', 'Wmc9', 'Wmc10', 'Wmc11', 'Wmc12', 'Wmc13', 'Wmc14', 'Wmc15', 'Wmc16', 'Wmc17', 'Wmc18', 'Wmc19', 'Wmc20', 'Wmc21', 'Wmc22', 'Wmc23', 'Wmc24', 'Wmc25', 'Wmc26', 'Wmc27', 'Wmc28', 'Wmc29', 'Wmc30', 'Wmc31', 'Wmc32', 'Wmc33', 'Wmc34', 'Wmc35', 'Wmc36', 'Wmc37', 'Wmc38', 'Wmc39', 'Wmc40', 'Wmc41', 'Wmc42', 'Wmc43', 'Wmc44', 'Wmc45', 'Wmc46', 'Wmc47', 'Wmc48', 'Wmc49', 'Wmc50', 'Wmc51', 'Wmc52', 'Wmc53', 'Wmc54', 'Wmc55', 'Wmc5
# ...

# %%
print(result2.columns.tolist())
# Out:
# ['Hue', 'Saturation', 'dominant_hue_1', 'dominant_sat_1', 'dominant_val_1', 'dominant_hue_2', 'dominant_sat_2', 'dominant_val_2', 'dominant_hue_3', 'dominant_sat_3', 'dominant_val_3', 'hue_contrast_c1_c2', 'hue_contrast_c1_c3', 'hue_contrast_c1_c4', 'hue_contrast_c1_c5', 'hue_contrast_c2_c3', 'hue_contrast_c2_c4', 'hue_contrast_c2_c5', 'hue_contrast_c3_c4', 'hue_contrast_c3_c5', 'hue_contrast_c4_c5', 'like_rate_segmentation', 'Number_of_Unique_Hues', 'Pixels_Belong_To_Dominant_Hue', 'like_rate', 'Entropy', 'like_rate_segmentation', 'michelson_contrast', 'Wmc', 'Wmc2', 'Wmc3', 'Wmc4', 'Wmc5', 'Wmc6', 'Wmc7', 'Wmc8', 'Wmc9', 'Wmc10', 'Wmc11', 'Wmc12', 'Wmc13', 'Wmc14', 'Wmc15', 'Wmc16', 'Wmc17', 'Wmc18', 'Wmc19', 'Wmc20', 'Wmc21', 'Wmc22', 'Wmc23', 'Wmc24', 'Wmc25', 'Wmc26', 'Wmc27', 'Wmc28', 'Wmc29', 'Wmc30', 'Wmc31', 'Wmc32', 'Wmc33', 'Wmc34', 'Wmc35', 'Wmc36', 'Wmc37', 'Wmc38', 'Wmc39', 'Wmc40', 'Wmc41', 'Wmc42', 'Wmc43', 'Wmc44', 'Wmc45', 'Wmc46', 'Wmc47', 'Wmc48', 'Wmc49', 'Wmc50'
# ...

# %%
print(resultsalience.columns.tolist())
# Out:
# ['Hue', 'Saturation', 'dominant_hue_1', 'dominant_sat_1', 'dominant_val_1', 'dominant_hue_2', 'dominant_sat_2', 'dominant_val_2', 'dominant_hue_3', 'dominant_sat_3', 'dominant_val_3', 'hue_contrast_c1_c2', 'hue_contrast_c1_c3', 'hue_contrast_c1_c4', 'hue_contrast_c1_c5', 'hue_contrast_c2_c3', 'hue_contrast_c2_c4', 'hue_contrast_c2_c5', 'hue_contrast_c3_c4', 'hue_contrast_c3_c5', 'hue_contrast_c4_c5', 'like_rate_segmentation', 'Number_of_Unique_Hues', 'Pixels_Belong_To_Dominant_Hue', 'Entropy', 'like_rate_segmentation', 'michelson_contrast', 'Wmc', 'Wmc2', 'Wmc3', 'Wmc4', 'Wmc5', 'Wmc6', 'Wmc7', 'Wmc8', 'Wmc9', 'Wmc10', 'Wmc11', 'Wmc12', 'Wmc13', 'Wmc14', 'Wmc15', 'Wmc16', 'Wmc17', 'Wmc18', 'Wmc19', 'Wmc20', 'Wmc21', 'Wmc22', 'Wmc23', 'Wmc24', 'Wmc25', 'Wmc26', 'Wmc27', 'Wmc28', 'Wmc29', 'Wmc30', 'Wmc31', 'Wmc32', 'Wmc33', 'Wmc34', 'Wmc35', 'Wmc36', 'Wmc37', 'Wmc38', 'Wmc39', 'Wmc40', 'Wmc41', 'Wmc42', 'Wmc43', 'Wmc44', 'Wmc45', 'Wmc46', 'Wmc47', 'Wmc48', 'Wmc49', 'Wmc50', 'Wmc51', 'W
# ...

# %%
print(result2salience.columns.tolist())
# Out:
# ['Hue', 'Saturation', 'dominant_hue_1', 'dominant_sat_1', 'dominant_val_1', 'dominant_hue_2', 'dominant_sat_2', 'dominant_val_2', 'dominant_hue_3', 'dominant_sat_3', 'dominant_val_3', 'hue_contrast_c1_c2', 'hue_contrast_c1_c3', 'hue_contrast_c1_c4', 'hue_contrast_c1_c5', 'hue_contrast_c2_c3', 'hue_contrast_c2_c4', 'hue_contrast_c2_c5', 'hue_contrast_c3_c4', 'hue_contrast_c3_c5', 'hue_contrast_c4_c5', 'Number_of_Unique_Hues', 'Pixels_Belong_To_Dominant_Hue', 'Entropy', 'like_rate_segmentation', 'michelson_contrast', 'Wmc', 'Wmc2', 'Wmc3', 'Wmc4', 'Wmc5', 'Wmc6', 'Wmc7', 'Wmc8', 'Wmc9', 'Wmc10', 'Wmc11', 'Wmc12', 'Wmc13', 'Wmc14', 'Wmc15', 'Wmc16', 'Wmc17', 'Wmc18', 'Wmc19', 'Wmc20', 'Wmc21', 'Wmc22', 'Wmc23', 'Wmc24', 'Wmc25', 'Wmc26', 'Wmc27', 'Wmc28', 'Wmc29', 'Wmc30', 'Wmc31', 'Wmc32', 'Wmc33', 'Wmc34', 'Wmc35', 'Wmc36', 'Wmc37', 'Wmc38', 'Wmc39', 'Wmc40', 'Wmc41', 'Wmc42', 'Wmc43', 'Wmc44', 'Wmc45', 'Wmc46', 'Wmc47', 'Wmc48', 'Wmc49', 'Wmc50', 'Wmc51', 'Wmc52', 'Wmc53', 'Wmc54', '
# ...

# %%
allfeaturesarc = pd.concat([result,resultsalience], axis=1)

# %%
allfeaturesart = pd.concat([result2,result2salience], axis=1)

# %%
allfeaturesarc.to_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\ALLFeatures_ARC.csv")
allfeaturesart.to_csv(r"C:\Users\Aziz\Desktop\Discovering How Low- and Mid-level Image Features Relate with Instagram Likes -Source Codes\CSV\ALLFeatures_ART.csv")
